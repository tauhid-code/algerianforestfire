# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Algerian_forest_fires_cleaned_dataset.csv')

# %%
df.head(3)
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4  7.6  1.3  3.4  0.5
# 1    2      6  2012           29  61  13   1.3  64.4  4.1  7.6  1.0  3.9  0.4
# 2    3      6  2012           26  82  22  13.1  47.1  2.5  7.1  0.3  2.7  0.1
#
#        Classes  Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0

# %%
df.drop(['day', 'month', 'year'], axis=1, inplace=True)

# %%
df.head(4)
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4  7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1  7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5  7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3  6.9  0.0  1.7  0.0  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
## Encoding
df['Classes'] = np.where(df['Classes'].str.contains("not fire"), 0, 1)

# %%
df.head(4)
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4  7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1  7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5  7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3  6.9  0.0  1.7  0.0        0       0

# %%
df.tail(5)
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
df["Classes"].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
## Independent and Dependent Features
X = df.drop('FWI', axis=1)
y = df['FWI']

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y.head()
# Out:
# 0    0.5
# 1    0.4
# 2    0.1
# 3    0.0
# 4    0.5
# Name: FWI, dtype: float64

# %%
X_train.head(4)
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI   BUI  Classes  Region
# 97            29  74  19   0.1  75.8   3.6  32.2   2.1   5.6        0       0
# 141           31  72  14   0.2  60.2   3.8   8.0   0.8   3.7        0       1
# 192           40  31  15   0.0  94.2  22.5  46.3  16.6  22.4        1       1
# 68            32  60  18   0.3  77.1  11.3  47.0   2.2  14.1        0       0

# %%
X_test.head(3)
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  Region
# 24            31  64  15   0.0  86.7  14.2  63.8  5.7  18.3        1       0
# 6             33  54  13   0.0  88.2   9.9  30.5  6.4  10.9        1       0
# 152           28  58  18   2.2  63.7   3.2   8.5  1.2   3.3        1       1

# %%
X_train.head(3)
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI   BUI  Classes  Region
# 97            29  74  19   0.1  75.8   3.6  32.2   2.1   5.6        0       0
# 141           31  72  14   0.2  60.2   3.8   8.0   0.8   3.7        0       1
# 192           40  31  15   0.0  94.2  22.5  46.3  16.6  22.4        1       1

# %%
X_test.head(3)
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  Region
# 24            31  64  15   0.0  86.7  14.2  63.8  5.7  18.3        1       0
# 6             33  54  13   0.0  88.2   9.9  30.5  6.4  10.9        1       0
# 152           28  58  18   2.2  63.7   3.2   8.5  1.2   3.3        1       1

# %%
import numpy as np                  ## Important CHATGPT KARA
import pandas as pd

# 1. ENCODE X_TEST
# Force the column to be of string/object type first, in case its dtype got messed up
# and then apply the encoding logic.
X_test['Classes'] = X_test['Classes'].astype(str)

# Apply the same encoding logic you used for X_train:
# Where 'Classes' contains "not fire", set the value to 0, otherwise set it to 1.
X_test['Classes'] = np.where(X_test['Classes'].str.contains("not fire"), 0, 1)


# 2. VERIFY DATA TYPES
# After this, ensure all columns in both X_train and X_test are numerical.
print("X_train dtypes:")
print(X_train.dtypes)

print("\nX_test dtypes:")
print(X_test.dtypes)

# Then you can run the correlation on X_train (and now X_test)
# X_train.corr()  <-- This should now work!
# Out:
# X_train dtypes:
# Temperature      int64
# RH               int64
# Ws               int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# Classes          int64
# Region           int64
# dtype: object
#
# X_test dtypes:
# Temperature      int64
# RH               int64
# Ws               int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# Classes          int64
# Region           int64
# dtype: object

# %%
## Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(X,y,test_size = 0.25, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
y_train.shape, y_test.shape
# Out:
# ((182,), (61,))

# %%
## Feature Selection based on correlation
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    int64
#  1   RH           243 non-null    int64
#  2   Ws           243 non-null    int64
#  3   Rain         243 non-null    float64
#  4   FFMC         243 non-null    float64
#  5   DMC          243 non-null    float64
#  6   DC           243 non-null    float64
#  7   ISI          243 non-null    float64
#  8   BUI          243 non-null    float64
#  9   FWI          243 non-null    float64
#  10  Classes      243 non-null    int64
#  11  Region       243 non-null    int64
# dtypes: float64(7), int64(5)
# memory usage: 22.9 KB

# %%
plt.figure(figsize=(12,10))
corr = X_train.corr()
sns.heatmap(corr, annot =True)
# Out:
# <Axes: >

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
           if abs(corr_matrix.iloc[i,j])>threshold:
               colname = corr_matrix.columns[i]
               col_corr.add(colname)
    return col_corr

# %%
corr_features=correlation(X_train, 0.85)

# %%
## Drop features with correlation higher than 85%

X_train.drop(corr_features, axis=1, inplace = True)
X_test.drop(corr_features, axis=1, inplace = True)

# %%
X_train.shape, X_test.shape
# Out:
# ((182, 9), (61, 9))

# %%
X_train.head()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC   ISI  Classes  Region
# 97            29  74  19   0.1  75.8   3.6   2.1        0       0
# 141           31  72  14   0.2  60.2   3.8   0.8        0       1
# 192           40  31  15   0.0  94.2  22.5  16.6        1       1
# 68            32  60  18   0.3  77.1  11.3   2.2        0       0
# 119           32  47  14   0.7  77.5   7.1   1.8        0       0

# %%
X_train.drop(['day', 'month', 'year'], axis=1, inplace=True)
X_test.drop(['day', 'month', 'year'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 X_train.drop(['day', 'month', 'year'], axis=1, inplace=True)
#       2 X_test.drop(['day', 'month', 'year'], axis=1, inplace=True)
#
# File c:\Users\Tauhid\Desktop\Code\.venv\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
# ...

# %%
## Feature Scaling and Standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.62963326,
#         -1.10431526, -0.98907071],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.93058524,
#         -1.10431526,  1.01105006],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  2.7271388 ,
#          0.90553851,  1.01105006],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.06948615,
#         -1.10431526, -0.98907071],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.5973248 ,
#          0.90553851,  1.01105006],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.86113478,
#         -1.10431526, -0.98907071]], shape=(182, 9))

# %%
## Box Plots to understand Effect of standard scaler
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title('X_train Before Standardization')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train After Standardization')
# Out:
# Text(0.5, 1.0, 'X_train After Standardization')

# %% [markdown]
# Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
linreg = LinearRegression()
linreg.fit(X_train_scaled, y_train)
y_pred = linreg.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'MAE: {mae}, MSE: {mse}, R2: {r2}')
plt.scatter(y_test, y_pred)
# Out:
# MAE: 0.7296708304778061, MSE: 1.0670943963502801, R2: 0.9758906166241712

# %% [markdown]
# Lasso Regression Model

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
lasso = Lasso()
lasso.fit(X_train_scaled, y_train)
y_pred = lasso.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'MAE: {mae}, MSE: {mse}, R2: {r2}')
# Out:
# MAE: 1.133175994914409, MSE: 2.2483458918974772, R2: 0.9492020263112388

# %%
y_pred = lasso_cv.predict(X_test_scaled)
plt.scatter(y_test, y_pred)

# %% [markdown]
# Ridge Regression Model

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
ridge = Ridge()
ridge.fit(X_train_scaled, y_train)
y_pred = ridge.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)       
print(f'MAE: {mae}, MSE: {mse}, R2: {r2}')
# Out:
# MAE: 0.7663063809268867, MSE: 1.1412144896744458, R2: 0.9742159852589269

# %% [markdown]
# ElasticNet Regression Model

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
elasticNet = ElasticNet()
elasticNet.fit(X_train_scaled, y_train)
y_pred = elasticNet.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)       
print(f'MAE: {mae}, MSE: {mse}, R2: {r2}')
plt.scatter(y_test, y_pred)
# Out:
# MAE: 2.4332969394325477, MSE: 8.423209936895361, R2: 0.8096903157599946

# %% [markdown]
# Cross Validation Lasso

# %%
from sklearn.linear_model import LassoCV
lasso_cv = LassoCV(cv=5)
lasso_cv.fit(X_train_scaled, y_train)
# Out:
# LassoCV(cv=5)

# %%
lasso_cv.predict(X_test_scaled)
# Out:
# array([ 8.17490595e+00,  7.68312478e+00,  7.30309292e-02,  5.05623019e+00,
#         6.78715772e+00,  2.10603942e+00,  2.23148094e+00,  7.64057821e+00,
#         2.32155940e+00,  3.72920653e+00,  9.57885456e-01,  1.02892511e+01,
#         9.36168319e+00,  1.69850366e+01,  1.82848876e+01,  1.94623725e+00,
#         1.95730894e+00, -3.11775123e-01,  7.28510526e+00,  3.10926518e+00,
#         2.28521520e+00,  5.10489526e-01,  6.47563129e+00,  4.72981202e-01,
#         2.09959701e+01,  5.11755206e+00,  5.86208849e+00,  9.75914403e+00,
#        -4.40578491e-01,  9.91838577e+00,  6.72277075e+00,  1.20361023e-02,
#         1.03110964e+01,  1.44365551e+01,  2.04002294e+00,  1.16419370e+00,
#         2.03414915e+00,  5.97488529e+00, -2.96568224e-01, -2.32206707e-01,
#         6.47253729e+00,  2.40951026e+00,  8.46741557e+00, -5.16651926e-01,
#         1.54044386e+01,  8.32941189e+00,  8.48782486e+00,  1.77009973e+00,
# ...

# %%
lasso_cv.alpha_
# Out:
# np.float64(0.05725391318234408)

# %%
lasso_cv.alphas_
# Out:
# array([7.05853002, 6.58280872, 6.13914944, 5.72539132, 5.33951911,
#        4.97965339, 4.64404142, 4.33104857, 4.03915039, 3.76692517,
#        3.51304702, 3.27627941, 3.05546914, 2.84954075, 2.65749124,
#        2.47838523, 2.31135036, 2.15557308, 2.01029467, 1.87480753,
#        1.74845178, 1.63061198, 1.52071419, 1.41822315, 1.32263965,
#        1.23349817, 1.15036452, 1.0728338 , 1.00052839, 0.93309613,
#        0.87020857, 0.81155943, 0.75686304, 0.705853  , 0.65828087,
#        0.61391494, 0.57253913, 0.53395191, 0.49796534, 0.46440414,
#        0.43310486, 0.40391504, 0.37669252, 0.3513047 , 0.32762794,
#        0.30554691, 0.28495408, 0.26574912, 0.24783852, 0.23113504,
#        0.21555731, 0.20102947, 0.18748075, 0.17484518, 0.1630612 ,
#        0.15207142, 0.14182231, 0.13226397, 0.12334982, 0.11503645,
#        0.10728338, 0.10005284, 0.09330961, 0.08702086, 0.08115594,
#        0.0756863 , 0.0705853 , 0.06582809, 0.06139149, 0.05725391,
# ...

# %%
lasso_cv.mse_path_
# Out:
# array([[53.64536329, 65.39074075, 54.89628985, 77.90299066, 39.38236846],
#        [46.99139716, 59.81506814, 49.29840831, 75.6645852 , 35.31758355],
#        [41.14908917, 53.9178721 , 42.49594889, 68.35708298, 31.76996123],
#        [36.05788169, 48.41773965, 36.66879347, 61.92819453, 28.67296816],
#        [31.62067285, 42.76466229, 31.68391904, 56.26841266, 24.93183295],
#        [27.75285367, 37.81922812, 27.42599138, 51.28216115, 21.56888645],
#        [24.3807738 , 33.49107651, 23.7950306 , 45.25481907, 18.66094162],
#        [21.44052804, 29.70161639, 20.70460191, 39.90418045, 16.14837778],
#        [18.876308  , 26.38208059, 18.07969934, 35.23429953, 13.97821475],
#        [16.63960395, 23.47341883, 15.85530749, 31.15712074, 12.10483403],
#        [14.68819307, 20.92329068, 13.97555108, 27.59649208, 10.48862803],
#        [12.98525144, 18.68636627, 12.39173305, 24.48611006,  9.09521221],
#        [11.49893734, 16.72312788, 11.06186319, 21.7677198 ,  7.89445038],
# ...

# %%
from sklearn.linear_model import RidgeCV
ridge_cv = RidgeCV(cv=5)
ridge_cv.fit(X_train_scaled, y_train)
y=pred = ridge_cv.predict(X_test_scaled)
plt.scatter(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'MAE: {mae}, MSE: {mse}, R2: {r2}')
# Out:
# MAE: 0.6562736168242879, MSE: 0.9006860610169465, R2: 0.9796503611858584

# %%
from sklearn.linear_model import ElasticNetCV
elastic_cv = ElasticNetCV(cv=5)
elastic_cv.fit(X_train_scaled, y_train)
y=pred = elastic_cv.predict(X_test_scaled)
plt.scatter(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'MAE: {mae}, MSE: {mse}, R2: {r2}')
# Out:
# MAE: 0.6562736168242879, MSE: 0.9006860610169465, R2: 0.9796503611858584

# %%
## Pickle the machine learning models, preprocessing standardscaler
scaler
# Out:
# StandardScaler()

# %%
ridge
# Out:
# Ridge()

# %%
import pickle
pickle.dump(scaler, open('scaler.pkl', 'wb'))
pickle.dump(ridge, open('ridge.pkl', 'wb'))
